# %%
import pandas as pd
import re
import numpy as np

# %%
df = pd.read_csv('test_result2.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline
from wordcloud import WordCloud, STOPWORDS
from matplotlib import cm
from pylab import rcParams

# %%
def convert(polarity):
  if polarity == '[1]':
    return positive
  elif polarity == '[0]':
    return neutral
  else:
    return negative

# %%
df.head()
# Out:
#                                                tweet polarity
# 0    0,how gig economy finally went into retreat via      [1]
# 1  1,gig economy organizations hire independent w...      [1]
# 2         2,glovo braced spain crackdown gig economy      [0]
# 3  3,hundreds deliveroo drivers planning strike c...     [-1]
# 4  4,how gig work gets defined will affect lives ...      [0]

# %%
final = df[['tweet', 'polarity']]

# %%
df['polarity'].value_counts().plot(kind='pie', figsize=(15, 10), autopct='%1.2f%%', shadow=True)

# %%
word_string=" ".join(df['tweet'])

def plot_cloud(wordcloud):
  plt.figure(figsize=(15, 10))  
  plt.imshow(wordcloud) 
  plt.axis('off')
  
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, 
background_color='black', colormap='Set2', collocations=False, 
stopwords = STOPWORDS).generate(word_string)

plot_cloud(wordcloud)
